# %% [markdown]
# # K Nearest Neighbors with Gzip

# %% [markdown]
# An implementation of K Nearest Neighbors using Gzip Normalized Compression Distances as embedding to train it

# %% [markdown]
# ## Imports

# %%
import gzip
import time
import pickle
import multiprocessing
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ## Load Dataset

# %%
# There are a total of 24639 samples
n_samples = 5000

df = pd.read_csv('./data/sentiment-emotion-labelled_Dell_tweets.csv')
df = df.truncate(0, n_samples)

# %% [markdown]
# ## Variables definition

# %%
X = df['Text']
X.head()
# Out:
# 0    @Logitech @apple @Google @Microsoft @Dell @Len...
# 1    @MK_habit_addict @official_stier @MortalKombat...
# 2    As @CRN celebrates its 40th anniversary, Bob F...
# 3    @dell your customer service is horrible especi...
# 4    @zacokalo @Dell @DellCares @Dell give the man ...
# Name: Text, dtype: object

# %%
y = df['sentiment']
y.head()
# Out:
# 0     neutral
# 1     neutral
# 2    positive
# 3    negative
# 4     neutral
# Name: sentiment, dtype: object

# %% [markdown]
# ## Data Cleaning and Preparation

# %%
X = X.str.replace(r'@[^ ]+', '', regex=True) # Remove tagged users
X = X.str.replace(r'#[^ ]+', '', regex=True) # Remove hashtags
X = X.str.replace(r'http[^ ]+', '', regex=True) # Remove hashtags
X.head()
# Out:
# 0           QWERTY were modified for programmers so...
# 1        She's getting a new   when the one she has...
# 2    As  its 40th anniversary, Bob Faletra and  wit...
# 3     your customer service is horrible especially ...
# 4                       give the man what he paid for!
# Name: Text, dtype: object

# %%
y_labels = {
    'positive': 1,
    'neutral': 0,
    'negative': -1
}

y = y.map(y_labels) # Map string labels to integers
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3   -1
# 4    0
# Name: sentiment, dtype: int64

# %% [markdown]
# ## Train/Test splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    random_state=1, 
                                                    stratify=y)

# %% [markdown]
# ## How to Normalize Compression Distances

# %%
X1_compressed = len(gzip.compress(X_train[0].encode()))
X1_compressed
# Out:
# 177

# %%
X2_compressed = len(gzip.compress(X_train[1].encode()))
X2_compressed
# Out:
# 121

# %%
XX = len(gzip.compress((" ".join([X_train[0], X_train[1]])).encode()))
XX
# Out:
# 255

# %%
NCD = (XX - min(X1_compressed, X2_compressed)) / max(X1_compressed, X2_compressed)
NCD
# Out:
# 0.7570621468926554

# %%
def calculate_ncd(x1, x2):
    X1_compressed = len(gzip.compress(x1.encode()))
    X2_compressed = len(gzip.compress(x2.encode()))  
    XX = len(gzip.compress((" ".join([x1, x2])).encode()))
  
    NCD = (XX - min(X1_compressed, X2_compressed)) / max(X1_compressed, X2_compressed)
    return NCD

# %%
def calculate_every_ncd(X_train):
   NCD = [[calculate_ncd(X_train.iloc[i], X_train.iloc[j]) for j in range(len(X_train))] for i in range(len(X_train))]
   return NCD

# %%
CPU_CORES = multiprocessing.cpu_count()

with multiprocessing.Pool(CPU_CORES) as pool:
    train_NCD = pool.apply(calculate_every_ncd, [X_train])

with multiprocessing.Pool(CPU_CORES) as pool:
    test_NCD = pool.map(calculate_every_ncd, [X_test])

# %%
with open('./serialized/test_NCD.pickle', 'wb') as path: 
    pickle.dump(test_NCD, path)

with open('./serialized/train_NCD.pickle', 'wb') as path: 
    pickle.dump(train_NCD, path)

# %% [markdown]
# ## Training

# %%
with open('./serialized/test_NCD.pickle', 'rb') as path: 
    unpickler = pickle.Unpickler(path)
    test_NCD = unpickler.load()

with open('./serialized/train_NCD.pickle', 'rb') as path: 
    unpickler = pickle.Unpickler(path)
    train_NCD = unpickler.load()

# %%
# KNN classification
knn = KNeighborsClassifier(n_neighbors=7) 
knn.fit(train_NCD, y_train)

print("Accuracy: ", knn.score(test_NCD, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[110], line 7
#       5 # KNN classification
#       6 knn = KNeighborsClassifier(n_neighbors=7)
# ----> 7 knn.fit(train_NCD, y_train)
#       9 print("Accuracy: ", knn.score(test_NCD, y_test))
#
# File ~/.pyenv/versions/3.10.12/envs/notebook/lib/python3.10/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/.pyenv/versions/3.10.12/envs/notebook/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:228, in KNeighborsClassifier.fit(self, X, y)
#     206 @_fit_context(
#     207     # KNeighborsClassifier.metric is not validated yet
#     208     prefer_skip_nested_validation=False
#     209 )
#     210 def fit(self, X, y):
#     211     """Fit the k-nearest neighbors classifier from the training dataset.
#     212
#     213     Parameters
#    (...)
#     226         The fitted k-nearest neighbors classifier.
#     227     """
# --> 228     return self._fit(X, y)
#
# File ~/.pyenv/versions/3.10.12/envs/notebook/lib/python3.10/site-packages/sklearn/neighbors/_base.py:456, in NeighborsBase._fit(self, X, y)
#     454 if self._get_tags()["requires_y"]:
#     455     if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 456         X, y = self._validate_data(
#     457             X, y, accept_sparse="csr", multi_output=True, order="C"
#     458         )
#     460     if is_classifier(self):
#     461         # Classification targets require a specific format
#     462         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# File ~/.pyenv/versions/3.10.12/envs/notebook/lib/python3.10/site-packages/sklearn/base.py:621, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     619         y = check_array(y, input_name="y", **check_y_params)
#     620     else:
# --> 621         X, y = check_X_y(X, y, **check_params)
#     622     out = X, y
#     624 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/.pyenv/versions/3.10.12/envs/notebook/lib/python3.10/site-packages/sklearn/utils/validation.py:1147, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1142         estimator_name = _check_estimator_name(estimator)
#    1143     raise ValueError(
#    1144         f"{estimator_name} requires y to be passed, but the target y is None"
#    1145     )
# -> 1147 X = check_array(
#    1148     X,
#    1149     accept_sparse=accept_sparse,
#    1150     accept_large_sparse=accept_large_sparse,
#    1151     dtype=dtype,
#    1152     order=order,
#    1153     copy=copy,
#    1154     force_all_finite=force_all_finite,
#    1155     ensure_2d=ensure_2d,
#    1156     allow_nd=allow_nd,
#    1157     ensure_min_samples=ensure_min_samples,
#    1158     ensure_min_features=ensure_min_features,
#    1159     estimator=estimator,
#    1160     input_name="X",
#    1161 )
#    1163 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1165 check_consistent_length(X, y)
#
# File ~/.pyenv/versions/3.10.12/envs/notebook/lib/python3.10/site-packages/sklearn/utils/validation.py:940, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     938     # If input is 1D raise error
#     939     if array.ndim == 1:
# --> 940         raise ValueError(
#     941             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     942             "Reshape your data either using array.reshape(-1, 1) if "
#     943             "your data has a single feature or array.reshape(1, -1) "
#     944             "if it contains a single sample.".format(array)
#     945         )
#     947 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#     948     raise ValueError(
#     949         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     950         "Convert your data to numeric values explicitly instead."
#     951     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[0.02604167 0.80208333 0.85022026 ... 0.83333333 0.77604167 0.78125   ].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
